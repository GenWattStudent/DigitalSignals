# %% [markdown]
# # Analiza Wektorów i IDFT
# Ten notebook zawiera analizę zadanych wektorów oraz syntezę sygnału za pomocą IDFT.

# %% [markdown]
# Instalacja Zależnośći

# %%
# %pip install numpy matplotlib fpdf
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %% [markdown]
# Tworzenie wykresu (część rzeczywista, część urojona).

# %%
import numpy as np
import matplotlib.pyplot as plt

x_mu = np.array([10, 5, 6, 6, 2, 4, 3, 4, 5, 0, 0, 0, 0], dtype=complex)
N = len(x_mu)

k = np.arange(N).reshape(N, 1)
n = np.arange(N).reshape(1, N)
W = np.exp(2j * np.pi * k @ n / N) / N 

time_signal = W @ x_mu

plt.figure(figsize=(10, 5))

plt.stem(np.real(time_signal), markerfmt='C0o', basefmt='C0:', linefmt='C0:', label='Real Part')
plt.stem(np.imag(time_signal), markerfmt='C1o', basefmt='C1:', linefmt='C1:', label='Imaginary Part')

plt.plot(np.real(time_signal), 'C0-', lw=0.5)
plt.plot(np.imag(time_signal), 'C1-', lw=0.5)

plt.xlabel('n')
plt.ylabel('Amplitude')
plt.title('Synthesized Signal using IDFT')

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Eksport do PDF
# Możemy wygenerować raport i zapisać go jako plik `.pdf`.

# %%
from fpdf import FPDF
import os

pdf = FPDF()
pdf.set_auto_page_break(auto=True, margin=15)
pdf.add_page()
pdf.set_font('Arial', 'B', 16)
pdf.cell(200, 10, 'Raport: IDFT Wektorów', ln=True, align='C')

pdf.set_font('Arial', '', 12)
pdf.cell(0, 10, f'Wektor {1}: {x_mu}', ln=True)

pdf_path = os.path.abspath("report.pdf")
pdf.output(pdf_path)

print(f'Zapisano raport jako: {pdf_path}')
print(f'Otwórz raport: file:///{pdf_path}')
# Out:
# Zapisano raport jako: c:\Users\Adrian\report.pdf
# Otwórz raport: file:///c:\Users\Adrian\report.pdf
